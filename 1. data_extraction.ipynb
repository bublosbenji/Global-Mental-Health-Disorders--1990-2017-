# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Importing the dataset

# %%
data = pd.read_csv('raw_mental_health_data.csv', low_memory=False)
data.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# 1        4.079531                   0.671768
# 2        4.088358                   0.670644
# 3        4.096190                   0.669738
# 4        4.099582                   0.669260

# %% [markdown]
# #### Upon examining the CSV file, I discovered it encompasses four tables, each with a unique structure. So I needed to extract these subtables from the raw data.

# %%
# identify the indices that distinguish the various tables within the raw CSV data
data[data.Year == 'Year']
# Out:
#          index  Entity  Code  Year  \
# 6468      6468  Entity  Code  Year
# 54276    54276  Entity  Code  Year
# 102084  102084  Entity  Code  Year
#
#                                         Schizophrenia (%)  \
# 6468                              Prevalence in males (%)
# 54276       Suicide rate (deaths per 100,000 individuals)
# 102084  Prevalence - Depressive disorders - Sex: Both ...
#
#                                      Bipolar disorder (%)  \
# 6468                            Prevalence in females (%)
# 54276   Depressive disorder rates (number suffering pe...
# 102084                                                NaN
#
#        Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 6468             Population                    NaN                     NaN
# 54276            Population                    NaN                     NaN
# 102084                  NaN                    NaN                     NaN
#
#         Depression (%)  Alcohol use disorders (%)
# 6468               NaN                        NaN
# 54276              NaN                        NaN
# 102084             NaN                        NaN

# %%
# dividing the tables
table1 = data.iloc[:6468]

table2 = data.iloc[6469:54276]
table2.columns = data.iloc[6468]
table2 = table2.iloc[:,:7].drop(columns = 6468)

table3 = data.iloc[54277:102084]
table3.columns = data.iloc[54276]
table3 = table3.iloc[:,:7].drop(columns = 54276)

table4 = data.iloc[102085:]
table4.columns = data.iloc[102084]
table4 = table4.iloc[:,:5].drop(columns = 102084)

# %% [markdown]
# #### Extracted 4 subtables from the raw data

# %%
from IPython.display import display

display(table1.head())
display(table2.head())
display(table3.head())
display(table4.head())
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# 1        4.079531                   0.671768
# 2        4.088358                   0.670644
# 3        4.096190                   0.669738
# 4        4.099582                   0.669260
# 6468       Entity Code  Year Prevalence in males (%)  \
# 6469  Afghanistan  AFG  1800                     NaN
# 6470  Afghanistan  AFG  1801                     NaN
# 6471  Afghanistan  AFG  1802                     NaN
# 6472  Afghanistan  AFG  1803                     NaN
# 6473  Afghanistan  AFG  1804                     NaN
#
# 6468 Prevalence in females (%) Population
# 6469                       NaN    3280000
# 6470                       NaN    3280000
# 6471                       NaN    3280000
# 6472                       NaN    3280000
# 6473                       NaN    3280000
# 54276       Entity Code  Year Suicide rate (deaths per 100,000 individuals)  \
# 54277  Afghanistan  AFG  1800                                           NaN
# 54278  Afghanistan  AFG  1801                                           NaN
# 54279  Afghanistan  AFG  1802                                           NaN
# 54280  Afghanistan  AFG  1803                                           NaN
# 54281  Afghanistan  AFG  1804                                           NaN
#
# 54276 Depressive disorder rates (number suffering per 100,000) Population
# 54277                                                NaN          3280000
# 54278                                                NaN          3280000
# 54279                                                NaN          3280000
# 54280                                                NaN          3280000
# 54281                                                NaN          3280000
# 102084       Entity Code  Year  \
# 102085  Afghanistan  AFG  1990
# 102086  Afghanistan  AFG  1991
# 102087  Afghanistan  AFG  1992
# 102088  Afghanistan  AFG  1993
# 102089  Afghanistan  AFG  1994
#
# 102084 Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
# 102085                                       318435.81367
# 102086                                      329044.773956
# 102087                                      382544.572895
# 102088                                      440381.507393
# 102089                                      456916.645489

# %% [markdown]
# #### Merging 4 subtables together

# %%
# filter out years between 1990-2017 and countries from table1

table1 = data.iloc[:6468].copy()
table1['Year'] = pd.to_numeric(table1['Year'], errors='coerce')

filtered_table1 = table1[(table1['Year'] >= 1990) & (table1['Year'] <= 2017)]

relevant_years = filtered_table1['Year'].unique()
relevant_entities = filtered_table1['Entity'].unique()

# filter out all 4 tables
def filter_table_by_criteria(table, years, entities):
    table['Year'] = pd.to_numeric(table['Year'], errors='coerce')
    return table[(table['Year'].isin(years)) & (table['Entity'].isin(entities))]

table2_filtered = filter_table_by_criteria(table2.copy(), relevant_years, relevant_entities)
table3_filtered = filter_table_by_criteria(table3.copy(), relevant_years, relevant_entities)
table4_filtered = filter_table_by_criteria(table4.copy(), relevant_years, relevant_entities)

# %%
# Convert 'Year' to integer before merging
table1['Year'] = pd.to_numeric(table1['Year'], errors='coerce').astype(int)
table2_filtered['Year'] = pd.to_numeric(table2_filtered['Year'], errors='coerce').astype(int)
table3_filtered['Year'] = pd.to_numeric(table3_filtered['Year'], errors='coerce').astype(int)
table4_filtered['Year'] = pd.to_numeric(table4_filtered['Year'], errors='coerce').astype(int)

# %%
# merging all 4 tables together based on key columns
from functools import reduce
import pandas as pd

tables_to_merge = [table1, table2_filtered, table3_filtered, table4_filtered]
merged_dataset = reduce(lambda left, right: pd.merge(left, right, on = ['Year', 'Code', 'Entity'], how = 'outer'), tables_to_merge)

# %%
merged_dataset
# Out:
#       index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0         0  Afghanistan  AFG  1990           0.16056             0.697779
# 1         1  Afghanistan  AFG  1991          0.160312             0.697961
# 2         2  Afghanistan  AFG  1992          0.160135             0.698107
# 3         3  Afghanistan  AFG  1993          0.160037             0.698257
# 4         4  Afghanistan  AFG  1994          0.160022             0.698469
# ...     ...          ...  ...   ...               ...                  ...
# 6463   6463     Zimbabwe  ZWE  2013           0.15567             0.607993
# 6464   6464     Zimbabwe  ZWE  2014          0.155993              0.60861
# 6465   6465     Zimbabwe  ZWE  2015          0.156465             0.609363
# 6466   6466     Zimbabwe  ZWE  2016          0.157111             0.610234
# 6467   6467     Zimbabwe  ZWE  2017          0.157963             0.611242
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0                0.101855               4.828830                1.677082
# 1                0.099313               4.829740                1.684746
# 2                0.096692               4.831108                1.694334
# 3                0.094336               4.830864                1.705320
# 4                0.092439               4.829423                1.716069
# ...                   ...                    ...                     ...
# 6463             0.117248               3.090168                0.766280
# 6464             0.118073               3.093964                0.768914
# 6465              0.11947               3.098687                0.771802
# 6466             0.121456               3.104294                0.772275
# 6467             0.124443               3.110926                0.772648
#
#       Depression (%)  Alcohol use disorders (%) Prevalence in males (%)  \
# 0           4.071831                   0.672404                3.499982
# 1           4.079531                   0.671768                3.503947
# 2           4.088358                   0.670644                3.508912
# 3           4.096190                   0.669738                3.513429
# 4           4.099582                   0.669260                3.515578
# ...              ...                        ...                     ...
# 6463        3.128192                   1.515641                2.769193
# 6464        3.140290                   1.515470                2.778101
# 6465        3.155710                   1.514751                2.789152
# 6466        3.174134                   1.513269                2.799308
# 6467        3.192789                   1.510943                2.812022
#
#      Prevalence in females (%)     Population_x  \
# 0                     4.647815  12412000.000000
# 1                     4.655772  13299000.000000
# 2                     4.662066  14486000.000000
# 3                     4.669012  15817000.000000
# 4                      4.67305  17076000.000000
# ...                        ...              ...
# 6463                  3.424106  13350000.000000
# 6464                  3.437674  13587000.000000
# 6465                  3.455323  13815000.000000
# 6466                  3.479071  14030000.000000
# 6467                   3.50086  14237000.000000
#
#      Suicide rate (deaths per 100,000 individuals)  \
# 0                                        10.318504
# 1                                         10.32701
# 2                                        10.271411
# 3                                        10.376123
# 4                                        10.575915
# ...                                            ...
# 6463                                       28.3612
# 6464                                     27.605547
# 6465                                     27.197061
# 6466                                     26.839591
# 6467                                     26.391769
#
#      Depressive disorder rates (number suffering per 100,000)  \
# 0                                           4039.755763
# 1                                           4046.256034
# 2                                           4053.709902
# 3                                           4060.203474
# 4                                           4062.290365
# ...                                                 ...
# 6463                                        3048.264249
# 6464                                        3056.996704
# 6465                                        3068.250731
# 6466                                        3081.782858
# 6467                                        3094.795065
#
#          Population_y  \
# 0     12412000.000000
# 1     13299000.000000
# 2     14486000.000000
# 3     15817000.000000
# 4     17076000.000000
# ...               ...
# 6463       13350000.0
# 6464       13587000.0
# 6465       13815000.0
# 6466       14030000.0
# 6467       14237000.0
#
#      Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
# 0                                          318435.81367
# 1                                         329044.773956
# 2                                         382544.572895
# 3                                         440381.507393
# 4                                         456916.645489
# ...                                                 ...
# 6463                                       303564.60359
# 6464                                      311665.769283
# 6465                                      320638.507158
# 6466                                      330437.353798
# 6467                                      340583.157405
#
# [6468 rows x 18 columns]

# %% [markdown]
# #### Creating a new CSV file from the merged tables

# %%
merged_dataset.to_csv('C:/Users/Benji/python_learn/global_mental_disorders/merged_dataset.csv', index=False)
